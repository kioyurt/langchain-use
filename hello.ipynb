# %%
from langchain_community.chat_models import ChatOpenAI
import os

# 设置环境变量

chat_model = ChatOpenAI(
    model_name="qwen-turbo",
    base_url="https://dashscope.aliyuncs.com/compatible-mode/v1",
    openai_api_key=""  # 显式传dd递API密钥
)

response = chat_model.invoke("什么是langchain")
print(response.content)
# Out:
# **LangChain** 是一个用于构建 **基于语言模型（LLM）的应用程序** 的开源框架，主要面向开发者和研究人员。它提供了一套工具、库和模块，帮助用户更高效地集成和使用像 GPT、Llama、Bert 等大型语言模型（LLM）。
#
# ---
#
# ## 🧠 什么是 LangChain？
#
# **LangChain** 是一个 **链式结构的开发框架**，它允许你将多个组件（如 LLM、数据源、工具等）连接起来，形成一个“链条”（chain），从而实现复杂的自然语言处理任务或应用。
#
# ---
#
# ## 📌 主要功能
#
# ### 1. **连接不同的语言模型**
# - 支持多种 LLM，包括：
#   - OpenAI 的 GPT 系列
#   - Hugging Face 的模型
#   - Llama、ChatGLM 等开源模型
# - 提供统一的接口调用这些模型
#
# ### 2. **构建 Chain（链）**
# - 将多个步骤串联成一个流程，例如：
#   - 输入文本 → 模型生成 → 后处理 → 输出结果
# - 支持串行、并行、条件分支等复杂逻辑
#
# ### 3. **与外部数据源集成**
# - 可以连接数据库、API、文件系统等
# - 实现 RAG（Retrieval-Augmented Generation）：从知识库中检索信息，再让模型生成回答
#
# ### 4. **工具集成**
# - 集成搜索工具、计算器、代码执行器等
# - 让 LLM 能够“调用工具”来完成更复杂任务
#
# ### 5. **Agent（智能体）**
# - 允许模型自主决定下一步操作
# - 基于环境反馈进行决策，比如选择使用哪个工具
#
# ---
#
# ## 🧰 核心组件
#
# | 组件 | 说明 |
# |------|------|
# | **LLM** | 大型语言模型，如 GPT、Llama |
# | **Prompt Templates** | 模板化输入提示，提高一致性 |
# | **Chains** | 将多个步骤组合为一个流程 |
# | **Agents** | 自主决策的智能体 |
# | **Memory** | 存储对话历史或其他上下文信息 |
# | **Retrievers** | 从知识库中检索信息（RAG） |
# | **Tools** | 外部工具，如搜索引擎、数据库查询等 |
#
# ---
#
# ## 🚀 示例场景
#
# ### 场景：问答系统（RAG）
# 1. 用户提问：“如何安装 Python？”
# 2. LangChain 从文档库中检索相关文章
# 3. 将检索到的信息和问题一起输入 LLM
# 4. LLM 生成简洁易懂的回答
#
# ### 场景：聊天机器人
# 1. 用户输入：“今天天气怎么样？”
# 2. Agent 决定调用天气 API
# 3. 获取天气信息后，用 LLM 生成自然语言回复
#
# ---
#
# ## 📚 安装方式
#
# ```bash
# pip install langchain
# ```
#
# ---
#
# ## ✅ 优点
#
# - **灵活**：支持各种 LLM 和自定义组件
# - **可扩展**：可以轻松添加新工具或数据源
# - **社区活跃**：有大量教程、插件和案例
#
# ---
#
# ## ⚠️ 注意事项
#
# - 对于复杂任务，需要合理设计“链”和“智能体”的逻辑
# - 需要一定的编程基础（Python）
#
# ---
#
# ## 🔗 相关资源
#
# - [LangChain 官网](https://www.langchain.com/)
# - [GitHub 仓库](https://github.com/langchain-ai/langchain)
# - [文档](https://python.langchain.com/docs/)
#
# ---
#
# 如果你是刚开始接触 LangChain，建议从官方教程入手，逐步构建你的第一个 LLM 应用！需要我帮你写一个简单的示例吗？
